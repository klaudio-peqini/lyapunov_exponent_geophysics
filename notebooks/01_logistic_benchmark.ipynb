# %% [markdown]
# # Logistic benchmark

# %%
from lyapgeo.benchmarks import logistic_series, logistic_true_lyapunov
from lyapgeo.workflows import run_methods, save_analysis_outputs
x = logistic_series(3.9, 0.2, n=6000, discard=1000)
print('True LE:', logistic_true_lyapunov(3.9, x))
results = run_methods(x, ['local','rosenstein','kantz'], 3, 1, 8, 1, 5, 20, 8, 3000, 0, 1000, 0.95, 'median')
save_analysis_outputs(results, 'notebook_results/logistic')
[(r.method, r.estimate, r.ci_low, r.ci_high, r.n_local) for r in results]
