# %% [markdown]
# # Geophysical time-series template

# %%
# from lyapgeo.io import read_series
# from lyapgeo.workflows import run_methods, save_analysis_outputs
# x = read_series('../data/raw/my_series.csv', column='value')
# results = run_methods(x, ['local','rosenstein','kantz'], 3, 2, 5, 0, 5, 20, 8, 5000, 0, 2000, 0.95, 'median')
# save_analysis_outputs(results, '../results/my_series')
